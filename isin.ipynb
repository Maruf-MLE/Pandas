# %%
import numpy as np
import pandas as pd

# %%
delivery=pd.read_csv('deliveries.csv')

# %%
mask=delivery['over']>=16 
death=delivery[mask]
death.sort_values('batsman')
# Out:
#        match_id  inning                 batting_team  \
# 98553       416       1          Sunrisers Hyderabad
# 91885       388       2          Sunrisers Hyderabad
# 91884       388       2          Sunrisers Hyderabad
# 91883       388       2          Sunrisers Hyderabad
# 91881       388       2          Sunrisers Hyderabad
# ...         ...     ...                          ...
# 16358        70       1  Royal Challengers Bangalore
# 16356        70       1  Royal Challengers Bangalore
# 16352        70       1  Royal Challengers Bangalore
# 29781       128       2               Mumbai Indians
# 16340        70       1  Royal Challengers Bangalore
#
#                       bowling_team  over  ball         batsman    non_striker  \
# 98553             Rajasthan Royals    18     5  A Ashish Reddy      DJG Sammy
# 91885  Royal Challengers Bangalore    17     6  A Ashish Reddy      GH Vihari
# 91884  Royal Challengers Bangalore    17     5  A Ashish Reddy      GH Vihari
# ...

# %%
death=pd.merge(death,ball_final,on='batsman',how='outer')
death
# Out:
#        match_id  inning      batting_team           bowling_team  over  ball  \
# 0           346       1   Deccan Chargers         Mumbai Indians    16     1
# 1           346       1   Deccan Chargers         Mumbai Indians    16     2
# 2           352       2   Deccan Chargers    Chennai Super Kings    19     5
# 3           352       2   Deccan Chargers    Chennai Super Kings    20     3
# 4           352       2   Deccan Chargers    Chennai Super Kings    20     4
# ...         ...     ...               ...                    ...   ...   ...
# 33732       578       1  Delhi Daredevils  Kolkata Knight Riders    18     4
# 33733       623       2  Delhi Daredevils         Mumbai Indians    19     1
# 33734       623       2  Delhi Daredevils         Mumbai Indians    19     2
# 33735       623       2  Delhi Daredevils         Mumbai Indians    19     4
# 33736       623       2  Delhi Daredevils         Mumbai Indians    20     1
#
# ...

# %%
death_final=death[['batsman','ball_counts']]
death_final
# Out:
#               batsman  ball_counts
# 0      A Ashish Reddy          148
# 1      A Ashish Reddy          148
# 2      A Ashish Reddy          148
# 3      A Ashish Reddy          148
# 4      A Ashish Reddy          148
# ...               ...          ...
# 33732          Z Khan          109
# 33733          Z Khan          109
# 33734          Z Khan          109
# 33735          Z Khan          109
# 33736          Z Khan          109
#
# [33737 rows x 2 columns]

# %%
death_final.drop_duplicates('ball_counts')
# Out:
#                batsman  ball_counts
# 0       A Ashish Reddy          148
# 148         A Chandila            7
# 155           A Chopra            2
# 157        A Choudhary           20
# 177         A Flintoff           18
# ...                ...          ...
# 31716          WP Saha          295
# 32079          Y Nagar          135
# 32214  Y Venugopal Rao          260
# 32475        YK Pathan          584
# 33112     Yuvraj Singh          516
#
# [163 rows x 2 columns]

# %%
mask3=death_final['ball_counts']>199
ball3=death_final[mask3].drop_duplicates('batsman').set_index('batsman')
ball3
# Out:
#                   ball_counts
# batsman
# A Mishra                  225
# AB de Villiers            570
# AD Mathews                289
# AM Nayar                  200
# AM Rahane                 268
# AR Patel                  229
# AT Rayudu                 425
# BJ Hodge                  385
# DA Miller                 360
# DA Warner                 228
# DJ Bravo                  409
# DJ Hussey                 234
# DPMD Jayawardene          246
# Harbhajan Singh           418
# IK Pathan                 465
# JA Morkel                 425
# JH Kallis                 231
# JP Duminy                 518
# JP Faulkner               294
# KA Pollard                838
# KD Karthik                463
# KM Jadhav                 338
# LRPL Taylor               204
# MK Pandey                 224
# MK Tiwary                 423
# MS Dhoni                 1224
# NV Ojha                   304
# P Kumar                   268
# PP Chawla                 311
# ...

# %%
runs
# Out:
# batsman
# A Ashish Reddy    214
# A Chandila          4
# A Chopra            1
# A Choudhary        25
# A Flintoff         25
#                  ...
# YS Chahal          15
# YV Takawale        29
# Yashpal Singh      17
# Yuvraj Singh      883
# Z Khan            108
# Name: batsman_runs, Length: 416, dtype: int64

# %%
mask=(death['over']>=16) & (death['ball_counts']>199)
death=death[mask]
df=death.sort_values('batsman')
df
# Out:
#        match_id  inning         batting_team                 bowling_team  \
# 239           5       2     Delhi Daredevils  Royal Challengers Bangalore
# 382         292       1      Deccan Chargers               Mumbai Indians
# 383         292       1      Deccan Chargers               Mumbai Indians
# 384         292       1      Deccan Chargers               Mumbai Indians
# 385         292       1      Deccan Chargers               Mumbai Indians
# ...         ...     ...                  ...                          ...
# 33275       161       2      Kings XI Punjab             Delhi Daredevils
# 33274       149       2      Kings XI Punjab          Chennai Super Kings
# 33273       149       2      Kings XI Punjab          Chennai Super Kings
# 33303       205       1      Kings XI Punjab  Royal Challengers Bangalore
# 33627       636       1  Sunrisers Hyderabad  Royal Challengers Bangalore
#
#        over  ball       batsman       non_striker       bowler  is_super_over  \
# ...

# %%
total_runs=df.groupby('batsman')['batsman_runs'].sum()

# %%
balls_counts=df.groupby('batsman')['ball_counts'].count()
ballf
# Out:
# batsman
# A Mishra             225
# AB de Villiers       570
# AD Mathews           289
# AM Nayar             200
# AM Rahane            268
# AR Patel             229
# AT Rayudu            425
# BJ Hodge             385
# DA Miller            360
# DA Warner            228
# DJ Bravo             409
# DJ Hussey            234
# DPMD Jayawardene     246
# Harbhajan Singh      418
# IK Pathan            465
# JA Morkel            425
# JH Kallis            231
# JP Duminy            518
# JP Faulkner          294
# KA Pollard           838
# KD Karthik           463
# KM Jadhav            338
# LRPL Taylor          204
# MK Pandey            224
# MK Tiwary            423
# MS Dhoni            1224
# NV Ojha              304
# P Kumar              268
# PP Chawla            311
# R Vinay Kumar        235
# RA Jadeja            576
# RG Sharma            748
# RV Uthappa           275
# S Badrinath          283
# S Dhawan             243
# SK Raina             458
# ...

# %%
sr=(total_runs/balls_counts)*100
sr.sort_values(ascending=False)
# Out:
# batsman
# AB de Villiers      211.052632
# DA Warner           189.473684
# DA Miller           186.666667
# V Kohli             181.868132
# RG Sharma           175.668449
# DJ Hussey           175.213675
# RV Uthappa          173.454545
# Yuvraj Singh        171.124031
# JH Kallis           170.562771
# MS Dhoni            169.607843
# SPD Smith           169.303797
# JP Duminy           167.760618
# DJ Bravo            167.726161
# SK Raina            167.467249
# AT Rayudu           165.411765
# WP Saha             163.389831
# KA Pollard          161.336516
# YK Pathan           159.246575
# S Dhawan            158.847737
# BJ Hodge            157.402597
# AM Nayar            155.000000
# AM Rahane           152.985075
# LRPL Taylor         152.941176
# KD Karthik          152.051836
# DPMD Jayawardene    152.032520
# MK Pandey           151.785714
# JA Morkel           149.882353
# JP Faulkner         149.319728
# S Badrinath         149.116608
# Y Venugopal Rao     148.846154
# ...
